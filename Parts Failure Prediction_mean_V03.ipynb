# %% [markdown]
# <h1> 1.Problem Statement</h1>

# %% [markdown]
# - The task is to come up with a good prediction model for judging whether or not a vehicle faces imminent failure of the specific component or not.
# - It will help in repairing of the vehical, if we know the part due to which the failure has accored.

# %% [markdown]
# <h2> 1.1 Dataset Description </h2>

# %% [markdown]
# <p>The dataset consists of data collected from heavy Scania trucks in everyday usage. The system in focus is the Air Pressure system (APS) which generates pressurised air that are utilized in various functions in a truck,
# such as braking and gear changes. The datasets' positive class consists of component failures
# for a specific component of the APS system. The negative class consists of trucks with failures
# for components not related to the APS. The data consists of a subset of all available data, selected by experts. The attribute names of the data have been anonymized for
# proprietary reasons.</p>

# %% [markdown]
# <h2> 1.2 Sources/Useful Links</h2>

# %% [markdown]
# - Source : https://ida2016.blogs.dsv.su.se/?page_id=1387

# %% [markdown]
# <h2>1.3 Real world/Business Objectives and Constraints </h2>

# %% [markdown]
# 1. The cost of a mis-classification can be very high.
# 3. No strict latency concerns.
# 4. Interpretability is partially important.
# 5. Metric : score = 500*FN + 10*FP

# %% [markdown]
# <h1>2. Machine Learning Probelm </h1>

# %% [markdown]
# <h3> 2.1.1 Data Overview </h3>

# %% [markdown]
# <p>
# - Data will be in a file Train.csv <br>
# - Train.csv contains 172 columns:<br>
# - Number of rows in Train.csv = 60,000
# </p>

# %% [markdown]
# <h2> 2.2 Mapping the real world problem to an ML problem </h2>

# %% [markdown]
# <h3> 2.2.1 Type of Machine Leaning Problem </h3>

# %% [markdown]
# <p> It is a binary classification problem, for the attribute we have to predict wwhether the failure has accoured due to some specific part or not.</p>

# %% [markdown]
# <h2> 2.3 Train and Test Construction </h2>

# %% [markdown]
# <p>  </p>
# <p> We build train and test by randomly splitting in the ratio of 70:30 or 80:20 whatever we choose as we have sufficient points to work with. </p>

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from fancyimpute import KNN, NuclearNormMinimization, SoftImpute, IterativeImputer, BiScaler
from statsmodels.imputation import mice
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import scikitplot as skplt
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_auc_score as AUC
from sklearn.metrics import roc_curve,auc
from sklearn import metrics
import xgboost as xgb
import numpy as np
import seaborn as sns
from prettytable import PrettyTable
from sklearn.decomposition import PCA
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698     na  2130706438    280      0      0      0      0      0
# 1   neg   33058     na           0     na      0      0      0      0      0
# 2   neg   41040     na         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874     na        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# 2      0
# 3     32
# 4      0
#
# [5 rows x 171 columns]

# %%
dp = data

# %%
data['class'].value_counts()
# Out:
# neg    59000
# pos     1000
# Name: class, dtype: int64

# %% [markdown]
# ### NOTE-> From the above result we can see that our data set is highly imbalanced, so simple accuracy score will not be a good measure of performance

# %%
Negative= data.loc[data['class'] == 'neg']  #extracting all the rows having negative class
Positive = data.loc[data['class']=='pos']  # extracting all the rows having positive class

# %% [markdown]
# ## Counting NAN values in all the columns corresponding to both the classes

# %%
def countna(x):
    count = 0
    for i in x:
        if i=='na':
            count = count+1
    return count

# %%
y1 = Negative['class']
y2 = Positive['class']

# %%
pos = Positive.drop(['class'],axis=1)
neg = Negative.drop(['class'],axis=1)

# %%
columns = pos.columns
count_na_n = {}  # counting nan for negative class
count_na_p = {}  # counting nan for positive class
for c_name in columns:
    count_na_n[c_name] = countna(neg[c_name].values)
for c_name in columns:
    count_na_p[c_name] = countna(pos[c_name].values)

# %%
plt.figure(figsize=(35,12))
plt.bar(count_na_n.keys(), count_na_n.values(),color='y')
plt.bar(count_na_p.keys(), count_na_p.values(),color='g')
plt.xticks([])
plt.xlabel("Columns of the Dataset",size=30)
plt.ylabel("Number of na values",size = 30)
plt.title("Histogram for number of na values for each column",size =30)
plt.legend(['Negative Class','Positive Class'])
plt.show()

# %% [markdown]
# 1. we can not sort the nan values as after doing sorting relative ordering of positive class columns and negative class relative ordering will change.
# 2. From the above histogram plot we can see that there are some columns in positive class that are having very few NAN but negative class is having lot of nan in those columns.

# %% [markdown]
# ## Percentage Number of nan values in positive and negative class in each column

# %%
def calperpos(d):
    per_p = {}
    for val in d.keys():
        per_p[val] = (d[val]*100)/1000.0
    return per_p
percentage_p = calperpos(count_na_p)

# %%
def calperneg(d):
    per_n = {}
    for val in d.keys():
        per_n[val] = (d[val]*100)/59000.0
    return per_n
percentage_n = calperneg(count_na_n)

# %%
plt.figure(figsize=(35,12))
plt.bar(percentage_n.keys(), percentage_n.values(),color='y')
plt.bar(percentage_p.keys(), percentage_p.values(),color='g')
plt.xticks([])
plt.xlabel("Columns of the Dataset",size=30)
plt.ylabel("Number of na values",size = 30)
plt.title("Histogram for percentage number of NAN values in positive and negative class ",size =30)
plt.legend(['Negative Class','Positive Class'])
plt.show()

# %% [markdown]
# 1. From the above histogram we can see that there is not equal percentage distribution of nan values in both positive and negative class.
# 2. In positive class, more number of columns are having high percentage of nan values as compare to negative class. In negative class a bunch of columns are having most of the nan values. But in positive it is distributed accross the columns.

# %% [markdown]
# ## count na or missing values in all the columns

# %%
def countna(x):
    count = 0
    for i in x:
        if i=='na':
            count = count+1
    return count

# %%
y = data['class']

# %%
data = data.drop(['class'],axis=1)

# %%
columns = data.columns
count_na = {}
for c_name in columns:
    count_na[c_name] = countna(data[c_name].values)

# %%
count_na
# Out:
# {'aa_000': 0,
#  'ab_000': 46329,
#  'ac_000': 3335,
#  'ad_000': 14861,
#  'ae_000': 2500,
#  'af_000': 2500,
#  'ag_000': 671,
#  'ag_001': 671,
#  'ag_002': 671,
#  'ag_003': 671,
#  'ag_004': 671,
#  'ag_005': 671,
#  'ag_006': 671,
#  'ag_007': 671,
#  'ag_008': 671,
#  'ag_009': 671,
#  'ah_000': 645,
#  'ai_000': 629,
#  'aj_000': 629,
#  'ak_000': 4400,
#  'al_000': 642,
#  'am_0': 629,
#  'an_000': 642,
#  'ao_000': 589,
#  'ap_000': 642,
#  'aq_000': 589,
#  'ar_000': 2723,
#  'as_000': 629,
#  'at_000': 629,
#  'au_000': 629,
#  'av_000': 2500,
#  'ax_000': 2501,
#  'ay_000': 671,
#  'ay_001': 671,
#  'ay_002': 671,
#  'ay_003': 671,
#  'ay_004': 671,
#  'ay_005': 671,
#  'ay_006': 671,
#  'ay_007': 671,
#  'ay_008': 671,
#  'ay_009': 671,
#  'az_000': 671,
#  'az_001': 671,
#  'az_002': 671,
#  'az_003': 671,
#  'az_004': 671,
#  'az_005': 671,
#  'az_006': 671,
#  'az_007': 671,
#  'az_008': 671,
#  'az_009': 671,
#  'ba_000': 688,
#  'ba_001': 688,
#  'ba_002': 688,
#  'ba_003': 688,
#  'ba_004': 688,
#  'ba_005': 688,
#  'ba_006': 688,
#  'ba_007': 688,
#  'ba_008': 688,
#  'ba_009': 688,
#  'bb_000': 645,
#  'bc_000': 2725,
#  'bd_000': 2727,
#  'be_000': 2503,
#  'bf_000': 2500,
#  'bg_000': 642,
#  'bh_000': 642,
#  'bi_000': 589,
#  'bj_000': 589,
#  'bk_000': 23034,
#  'bl_000': 27277,
#  'bm_000': 39549,
#  'bn_000': 44009,
#  'bo_000': 46333,
#  'bp_000': 47740,
#  'bq_000': 48722,
#  'br_000': 49264,
#  'bs_000': 726,
#  'bt_000': 167,
#  'bu_000': 691,
#  'bv_000': 691,
#  'bx_000': 3257,
#  'by_000': 473,
#  'bz_000': 2723,
#  'ca_000': 4356,
#  'cb_000': 726,
#  'cc_000': 3255,
#  'cd_000': 676,
#  'ce_000': 2502,
#  'cf_000': 14861,
#  'cg_000': 14861,
#  'ch_000': 14861,
#  'ci_000': 338,
#  'cj_000': 338,
#  'ck_000': 338,
#  'cl_000': 9553,
#  'cm_000': 9877,
#  'cn_000': 687,
#  'cn_001': 687,
#  'cn_002': 687,
#  'cn_003': 687,
#  'cn_004': 687,
#  'cn_005': 687,
#  'cn_006': 687,
#  'cn_007': 687,
#  'cn_008': 687,
#  'cn_009': 687,
#  'co_000': 14861,
#  'cp_000': 2724,
#  'cq_000': 691,
#  'cr_000': 46329,
#  'cs_000': 669,
#  'cs_001': 669,
#  'cs_002': 669,
#  'cs_003': 669,
#  'cs_004': 669,
#  'cs_005': 669,
#  'cs_006': 669,
#  'cs_007': 669,
#  'cs_008': 669,
#  'cs_009': 669,
#  'ct_000': 13808,
#  'cu_000': 13808,
#  'cv_000': 13808,
#  'cx_000': 13808,
#  'cy_000': 13808,
#  'cz_000': 13808,
#  'da_000': 13808,
#  'db_000': 13808,
#  'dc_000': 13808,
#  'dd_000': 2503,
#  'de_000': 2724,
#  'df_000': 4008,
#  'dg_000': 4008,
#  'dh_000': 4008,
#  'di_000': 4006,
#  'dj_000': 4007,
#  'dk_000': 4007,
#  'dl_000': 4008,
#  'dm_000': 4009,
#  'dn_000': 691,
#  'do_000': 2724,
#  'dp_000': 2726,
#  'dq_000': 2726,
#  'dr_000': 2726,
#  'ds_000': 2727,
#  'dt_000': 2727,
#  'du_000': 2726,
#  'dv_000': 2726,
#  'dx_000': 2723,
#  'dy_000': 2724,
#  'dz_000': 2723,
#  'ea_000': 2723,
#  'eb_000': 4007,
#  'ec_00': 10239,
#  'ed_000': 9553,
#  'ee_000': 671,
#  'ee_001': 671,
#  'ee_002': 671,
#  'ee_003': 671,
#  'ee_004': 671,
#  'ee_005': 671,
#  'ee_006': 671,
#  'ee_007': 671,
#  'ee_008': 671,
#  'ee_009': 671,
#  'ef_000': 2724,
#  'eg_000': 2723}

# %%
sorted_d = sorted(count_na.items(), key=lambda x: x[1])

# %%
def Reverse(lst): 
    return [ele for ele in reversed(lst)] 
sorted_d = Reverse(sorted_d)

# %%
count_na = {}
for kv in sorted_d:
    count_na[kv[0]] = kv[1]

# %%
plt.figure(figsize=(35,12))
plt.bar(count_na.keys(), count_na.values(),color='g')
plt.xticks([])
plt.xlabel("Columns of the Dataset",size=30)
plt.ylabel("Number of na values",size = 30)
plt.title("Histogram for number of na values for each column",size =30)
plt.show()

# %%
 sorted_d = sorted_d[:50]

# %%
count_na = {}
for kv in sorted_d:
    count_na[kv[0]] = kv[1]

# %%
plt.figure(figsize=(35,12))
plt.bar(count_na.keys(), count_na.values(),color='g')
plt.xticks([])
plt.xlabel("Columns of the Dataset",size=30)
plt.ylabel("Number of na values",size = 30)
plt.title("Histogram for number of na values for each column",size =30)
plt.show()

# %%
 sorted_d = sorted_d[:25]

# %%
count_na = {}
for kv in sorted_d:
    count_na[kv[0]] = kv[1]

# %%
plt.figure(figsize=(20,12))
plt.bar(count_na.keys(), count_na.values(),color='g')
plt.xticks([])
plt.xlabel("Columns of the Dataset",size=30)
plt.ylabel("Number of na values",size = 30)
plt.title("Histogram for number of na values for each column",size =30)
plt.show()

# %% [markdown]
# 1. From the above plot we can see that there are some attributes in the dataset for which more than 50% cells are NAN so we will drop those columns

# %% [markdown]
# ## Percentage na value

# %%
per_count = {}
for i in count_na.keys():
    val = count_na[i]
    per = (val/60000)*100
    if per>=50:
        per_count[i]=per

# %%
print("Columns having more that 50% missing or na values and thier percentage :")
per_count
# Out:
# Columns having more that 50% missing or na values and thier percentage :
# {'br_000': 82.10666666666665,
#  'bq_000': 81.20333333333333,
#  'bp_000': 79.56666666666666,
#  'bo_000': 77.22166666666666,
#  'cr_000': 77.215,
#  'ab_000': 77.215,
#  'bn_000': 73.34833333333334,
#  'bm_000': 65.915}

# %% [markdown]
# 1. From the above result we can see that there are 8 columns that are having more that 50% values as na so we will simply drop them from the dataset

# %%
## Droping the columns having more than 50% na values
data = data.drop(['ab_000','bm_000','bn_000','bo_000','bp_000','bq_000','br_000','cr_000'],axis=1)
print("After droping the columns having 50% or more missing values shape of the dataset",data.shape)
# Out:
# After droping the columns having 50% or more missing values shape of the dataset (60000, 162)

# %% [markdown]
# ## Using simple mean for data imputation

# %%
data.head()
# Out:
#    aa_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002 ag_003 ag_004  \
# 0   76698  2130706438    280      0      0      0      0      0      0  37250
# 1   33058           0     na      0      0      0      0      0      0  18254
# 2   41040         228    100      0      0      0      0      0      0   1648
# 3      12          70     66      0     10      0      0      0    318   2212
# 4   60874        1368    458      0      0      0      0      0      0  43752
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# 2      0
# 3     32
# 4      0
#
# [5 rows x 162 columns]

# %%
data.dtypes
# Out:
# aa_000     int64
# ac_000    object
# ad_000    object
# ae_000    object
# af_000    object
# ag_000    object
# ag_001    object
# ag_002    object
# ag_003    object
# ag_004    object
# ag_005    object
# ag_006    object
# ag_007    object
# ag_008    object
# ag_009    object
# ah_000    object
# ai_000    object
# aj_000    object
# ak_000    object
# al_000    object
# am_0      object
# an_000    object
# ao_000    object
# ap_000    object
# aq_000    object
# ar_000    object
# as_000    object
# at_000    object
# au_000    object
# av_000    object
#            ...
# dl_000    object
# dm_000    object
# dn_000    object
# do_000    object
# dp_000    object
# dq_000    object
# dr_000    object
# ds_000    object
# dt_000    object
# du_000    object
# dv_000    object
# dx_000    object
# dy_000    object
# dz_000    object
# ea_000    object
# eb_000    object
# ec_00     object
# ed_000    object
# ee_000    object
# ee_001    object
# ee_002    object
# ee_003    object
# ee_004    object
# ee_005    object
# ee_006    object
# ee_007    object
# ee_008    object
# ee_009    object
# ef_000    object
# eg_000    object
# Length: 162, dtype: object

# %%
#function to convert all the data columns to numeric
def convert_numeric(x):
    d = []
    for y in x:
        if y=='na':
            d.append(np.nan)
        else:
            d.append(float(y))
    return d

# %%
## Converting all columns to numeric:
cl = data.columns
num_data = pd.DataFrame()
for d in range(0,len(cl)):
        num_data[cl[d]] = convert_numeric(data[cl[d]].values)

# %%
num_data.dtypes
# Out:
# aa_000    float64
# ac_000    float64
# ad_000    float64
# ae_000    float64
# af_000    float64
# ag_000    float64
# ag_001    float64
# ag_002    float64
# ag_003    float64
# ag_004    float64
# ag_005    float64
# ag_006    float64
# ag_007    float64
# ag_008    float64
# ag_009    float64
# ah_000    float64
# ai_000    float64
# aj_000    float64
# ak_000    float64
# al_000    float64
# am_0      float64
# an_000    float64
# ao_000    float64
# ap_000    float64
# aq_000    float64
# ar_000    float64
# as_000    float64
# at_000    float64
# au_000    float64
# av_000    float64
#            ...
# dl_000    float64
# dm_000    float64
# dn_000    float64
# do_000    float64
# dp_000    float64
# dq_000    float64
# dr_000    float64
# ds_000    float64
# dt_000    float64
# du_000    float64
# dv_000    float64
# dx_000    float64
# dy_000    float64
# dz_000    float64
# ea_000    float64
# eb_000    float64
# ec_00     float64
# ed_000    float64
# ee_000    float64
# ee_001    float64
# ee_002    float64
# ee_003    float64
# ee_004    float64
# ee_005    float64
# ee_006    float64
# ee_007    float64
# ee_008    float64
# ee_009    float64
# ef_000    float64
# eg_000    float64
# Length: 162, dtype: object

# %% [markdown]
# ### Imputation using mean
# 1. It is very simple approch yet very powerful. We are going to replace all the nan values in a column by the mean value in of the column.
# 2. It works on the assumption that the missing values are missing completely at random.

# %%
#imputation using mean 
data = num_data.fillna(num_data.mean(),inplace = False) # data is containing my final data after imputation

# %%
## Converting Y values as Numeric
d_class = []
for d in y.values:
    if d=='neg':
        d_class.append(0)
    else:
        d_class.append(1)

# %%
data['class'] = d_class

# %%
data.head()
# Out:
#     aa_000        ac_000         ad_000  ae_000  af_000  ag_000  ag_001  \
# 0  76698.0  2.130706e+09     280.000000     0.0     0.0     0.0     0.0
# 1  33058.0  0.000000e+00  190620.639314     0.0     0.0     0.0     0.0
# 2  41040.0  2.280000e+02     100.000000     0.0     0.0     0.0     0.0
# 3     12.0  7.000000e+01      66.000000     0.0    10.0     0.0     0.0
# 4  60874.0  1.368000e+03     458.000000     0.0     0.0     0.0     0.0
#
#    ag_002  ag_003   ag_004  ...    ee_003    ee_004    ee_005    ee_006  \
# 0     0.0     0.0  37250.0  ...  493384.0  721044.0  469792.0  339156.0
# 1     0.0     0.0  18254.0  ...  178064.0  293306.0  245416.0  133654.0
# 2     0.0     0.0   1648.0  ...  159812.0  423992.0  409564.0  320746.0
# 3     0.0   318.0   2212.0  ...      46.0      58.0      44.0      10.0
# 4     0.0     0.0  43752.0  ...  229790.0  405298.0  347188.0  286954.0
#
#      ee_007    ee_008  ee_009  ef_000  eg_000  class
# 0  157956.0   73224.0     0.0     0.0     0.0      0
# 1   81140.0   97576.0  1500.0     0.0     0.0      0
# 2  158022.0   95128.0   514.0     0.0     0.0      0
# 3       0.0       0.0     0.0     4.0    32.0      0
# 4  311560.0  433954.0  1218.0     0.0     0.0      0
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Splitting the datainto train test and cv

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(['class'],axis=1),data['class'], test_size=0.20, random_state=42)
X_train, X_cv, y_train,y_cv = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
#if enable_normalization and normalization_type=='minmax':
scaler = MinMaxScaler().fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_cv.columns)
X_cv = pd.DataFrame(scaler.transform(X_cv), columns=X_cv.columns)

# %%
## method to create the heat map for cross validation 
def createHeatMap(alpha,gamma1,roc_auc_cv1):
    l = []
    for i in alpha:
        for g in gamma1:
            l.append([i,g])
    l = np.asarray(l)
    df = pd.DataFrame(l, columns=['depth','estimators'])
    df['cv_score'] = roc_auc_cv1
    df.head()
    sns.set()
    data = df.pivot("depth", "estimators", "cv_score")
    ax = sns.heatmap(data, annot=True, fmt=".3f")

# %%
def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
            TP += 1
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
            FP += 1
        if y_actual[i]==y_hat[i]==0:
            TN += 1
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
            FN += 1

    return(TP, FP, TN, FN)

# %% [markdown]
# ## Naive Bayes
# 1. As we know naive works well when dimensionality of the dataset is large, Naive Bayes performs well. So we are using naive on this dataset as well.

# %%
def cal_acc(test,k):
    predict_val = []
   # print(test)
    for d in test:
            if d[0]>k:
                predict_val.append(0)
            else:
                predict_val.append(1)
    return predict_val

# %%
gnb = GaussianNB()
gnb.fit(X_train,y_train)
predict_train = gnb.predict_proba(X_train)
predict_test = gnb.predict_proba(X_test)

# %%
for k in [.89990000999991]:#,.025,.05,.1,.2,.3,.4,.5,.6,.7,.8,.9,.99]:
    predict1 = cal_acc(predict_test,k)
    predict2 = cal_acc(predict_train,k)
    print("Test Accuracy score of the model :",accuracy_score(y_test,predict1))
    print("Train Accuracy score of the model :",accuracy_score(y_train,predict2))
# Out:
# Test Accuracy score of the model : 0.9619166666666666
# Test Accuracy score of the model : 0.965859375

# %%
#confusion matrix for test data
skplt.metrics.plot_confusion_matrix(y_test,predict1)

# %%
##confusiion matrix for train data
skplt.metrics.plot_confusion_matrix(y_train,predict2)

# %%
train_score = 78*500+1140*10
test_score = 17*500+387*10
print("Training score using given metric : ",train_score)
print("Test score using given metric :",test_score)
# Out:
# Training score using given metric :  50400
# Test score using given metric : 12370

# %% [markdown]
# ## Random Forest Classifier

# %%
depth=[1,10,30, 100,300]
est=[1,10,50,150,200]
roc_auc_cv = []              # to store the cross validation accuracy on the cv dataset (final_cv)
roc_auc_train= []            # to store the training accuracy on the training dataset (final_train)
cv_acc=0
max_auc = 0
opt_sample_est = 0
opt_depth = 0
opt_val_cv = 99999999999999999999999
opt_val_train = 0
train_val = []
cv_val = []
for d in depth:
    for s in est:
        clf = RFC(n_estimators = 1,max_depth = 1,n_jobs=-1)
        clf.fit(X_train,y_train)
        cv_prediction = clf.predict_proba(X_cv)[:,1]
        train_prediction = clf.predict_proba(X_train)[:,1]
        cv_prediction1 = clf.predict(X_cv)
        train_prediction1 = clf.predict(X_train)
        cv_auc = roc_auc_score(y_cv, cv_prediction)
        train_acc = roc_auc_score(y_train,train_prediction)
        ## calculating fp,pn,tn,tp
        X1 = perf_measure(y_cv.values,cv_prediction1)
        X2 = perf_measure(y_train.values,train_prediction1)
        v1 = X1[3]*500 + X1[1]*10
        v2 = X2[3]*500 + X2[1]*10
        train_val.append(v2)
        cv_val.append(v1)
        #skplt.metrics.plot_confusion_matrix(y_cv,cv_prediction1)
        if(opt_val_cv > v1):
            opt_val_cv = v1
            opt_val_train = v2
            opt_depth = d
            opt_sample_est = s
            max_auc = cv_auc
        roc_auc_cv.append(cv_auc)
        roc_auc_train.append(train_acc)   
print("Optimal Cross Validation Error : ",opt_val_cv)
print("Train Error on Optimal CV Error : ",opt_val_train)
print("Max ROC_AUC Score :",max_auc)
print("Optimal_depth of the decision tree :",opt_depth)
print("Optimal No of estimators:",opt_sample_est)
# Out:
# Optimal Cross Validation Error :  43880
# Train Error on Optimal CV Error :  181740
# Max ROC_AUC Score : 0.6937951020112382
# Optimal_depth of the decision tree : 10
# Optimal No of estimators: 50

# %% [markdown]
# ####  Heat map for error (500*FN+10*FP)

# %%
plt.figure(figsize=(10,7))
print("Heat Map on train data:")
createHeatMap(depth,est,train_val)
# Out:
# Heat Map on train data:

# %%
plt.figure(figsize=(10,10))
print("Heat Map for Training data:")
createHeatMap(depth,est,cv_val)
# Out:
# Heat Map for Training data:

# %% [markdown]
# #### CV Score

# %%
print("Heat Map on CV data:")
createHeatMap(depth,est,roc_auc_cv)
# Out:
# Heat Map on CV data:

# %%
print("Heat Map for Training data:")
createHeatMap(depth,est,roc_auc_train)
# Out:
# Heat Map for Training data:

# %%
clf = RFC(n_estimators = 50,max_depth = 10,n_jobs=-1)
clf.fit(X_train,y_train)
predict_train = clf.predict_proba(X_train)
predict_test = clf.predict_proba(X_test)
predict1 = cal_acc(predict_test,k)
predict2 = cal_acc(predict_train,k)
#print("Train Accuracy of the model : ",accuracy_score(y_train,predict_train))
#print("Test accuracy of the model :",accuracy_score(y_test,predict_test))

# %%
for k in [.9799880]:#,.025,.05,.1,.2,.3,.4,.5,.6,.7,.8,.9,.99]:
    predict1 = cal_acc(predict_test,k)
    predict2 = cal_acc(predict_train,k)
    print("Test Accuracy score of the model :",accuracy_score(y_test,predict1))
    print("Train Accuracy score of the model :",accuracy_score(y_train,predict2))
# Out:
# Test Accuracy score of the model : 0.94975
# Test Accuracy score of the model : 0.97

# %%
#confusion matrix for test data
skplt.metrics.plot_confusion_matrix(y_test,predict1)

# %%
#confusion matrix for train data
skplt.metrics.plot_confusion_matrix(y_train,predict2)

# %%
train_fpr, train_tpr, thresholds = roc_curve(y_train, clf.predict_proba(X_train)[:,1])
test_fpr, test_tpr, thresholds1 = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
plt.plot(train_fpr, train_tpr, label="train AUC ="+str(metrics.auc(train_fpr, train_tpr)))
plt.plot(test_fpr, test_tpr, label="test AUC ="+str(metrics.auc(test_fpr, test_tpr)))
plt.legend()
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC curve")
plt.show()

# %%
train_score = 500*10+10*566
test_score = 12*500+1102*10
print("Training score using given metric : ",train_score)
print("Test score using given metric :",test_score)
# Out:
# Training score using given metric :  10660
# Test score using given metric : 17020

# %% [markdown]
# ### XGboost Model

# %%
depth=[1,10,30,100,200]
est=[1,10,50,150,300]
roc_auc_cv = []              # to store the cross validation accuracy on the cv dataset (final_cv)
roc_auc_train= []            # to store the training accuracy on the training dataset (final_train)
cv_acc=0
max_auc = 0
opt_sample_est = 0
opt_depth = 0
train_val,cv_val = [],[]
opt_val_cv,opt_val_train = 9999999999999999999999,0
for d in depth:
    for s in est:
        clf = xgb.XGBClassifier(n_estimators = s,max_depth = d,n_jobs = -1)
        clf.fit(X_train,y_train)
        cv_prediction = clf.predict_proba(X_cv)
        train_prediction = clf.predict_proba(X_train)
        cv_prediction1 = clf.predict(X_cv)
        train_prediction1 = clf.predict(X_train)
        #print(y_cv)
       # cv_auc = roc_auc_score(y_cv, cv_prediction)
       # train_acc = roc_auc_score(y_train,train_prediction)
        
        
        
        for k in [.999]:#,.025,.05,.1,.2,.3,.4,.5,.6,.7,.8,.9,.99]:
            predict1 = cal_acc(cv_prediction, k)
            predict2 = cal_acc(train_prediction, k)
            print("Test Accuracy score of the model :",accuracy_score(y_cv,predict1))
            print("Test Accuracy score of the model :",accuracy_score(y_train,predict2))
        
        ## calculating fp,pn,tn,tp
        cv_prediction1 = predict1
        train_prediction1 = predict2
        X1 = perf_measure(y_cv.values,cv_prediction1)
        X2 = perf_measure(y_train.values,train_prediction1)
        v1 = X1[3]*500 + X1[1]*10
        v2 = X2[3]*500 + X2[1]*10
        train_val.append(v2)
        cv_val.append(v1)
        #skplt.metrics.plot_confusion_matrix(y_cv,cv_prediction1)
        if(opt_val_cv > v1):
            opt_val_cv = v1
            opt_val_train = v2
            opt_depth = d
            opt_sample_est = s
            max_auc = cv_auc
        roc_auc_cv.append(cv_auc)
        roc_auc_train.append(train_acc)   
print("Optimal Cross Validation Error : ",opt_val_cv)
print("Train Error on Optimal CV Error : ",opt_val_train)
print("Max ROC_AUC Score :",max_auc)
print("Optimal_depth of the decision tree :",opt_depth)
print("Optimal No of estimators:",opt_sample_est)
# Out:
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9878125
# Test Accuracy score of the model : 0.986640625
# Test Accuracy score of the model : 0.9909375
# Test Accuracy score of the model : 0.9910677083333334
# Test Accuracy score of the model : 0.9920833333333333
# Test Accuracy score of the model : 0.9931770833333333
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9928125
# Test Accuracy score of the model : 0.9971614583333334
# Test Accuracy score of the model : 0.994375
# Test Accuracy score of the model : 0.9995833333333334
# Test Accuracy score of the model : 0.9940625
# Test Accuracy score of the model : 0.9999739583333334
# Test Accuracy score of the model : 0.9940625
# Test Accuracy score of the model : 0.9999739583333334
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9938541666666667
# Test Accuracy score of the model : 0.998046875
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9996354166666667
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9999739583333334
# Test Accuracy score of the model : 0.9944791666666667
# Test Accuracy score of the model : 1.0
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9938541666666667
# Test Accuracy score of the model : 0.998046875
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9996354166666667
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9999739583333334
# Test Accuracy score of the model : 0.9944791666666667
# Test Accuracy score of the model : 1.0
# Test Accuracy score of the model : 0.9851041666666667
# Test Accuracy score of the model : 0.983203125
# Test Accuracy score of the model : 0.9938541666666667
# Test Accuracy score of the model : 0.998046875
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9996354166666667
# Test Accuracy score of the model : 0.9942708333333333
# Test Accuracy score of the model : 0.9999739583333334
# Test Accuracy score of the model : 0.9944791666666667
# Test Accuracy score of the model : 1.0
# Optimal Cross Validation Error :  24050
# Train Error on Optimal CV Error :  0
# Max ROC_AUC Score : 0.865084952057565
# Optimal_depth of the decision tree : 30
# Optimal No of estimators: 300

# %% [markdown]
# ### heat map for error

# %%
plt.figure(figsize=(10,7))
print("Heat Map on train data:")
createHeatMap(depth,est,train_val)
# Out:
# Heat Map on train data:

# %%
plt.figure(figsize=(10,7))
print("Heat Map on CV data:")
createHeatMap(depth,est,cv_val)
# Out:
# Heat Map on CV data:

# %% [markdown]
# ### Heat map for auc_roc score

# %%
createHeatMap(depth,est,roc_auc_cv)

# %%
createHeatMap(depth,est,roc_auc_train)

# %%
clf = xgb.XGBClassifier(n_estimators = 300,max_depth =30,n_jobs = -1)
clf.fit(X_train,y_train)
predict_train = clf.predict_proba(X_train)
predict_test = clf.predict_proba(X_test)

# %%
for k in [.9990]:
    predict1 = cal_acc(predict_test,k)
    predict2 = cal_acc(predict_train,k)
    print("Test Accuracy score of the model :",accuracy_score(y_test,predict1))
    print("Train Accuracy score of the model :",accuracy_score(y_train,predict2))
# Out:
# Test Accuracy score of the model : 0.9636666666666667
# Test Accuracy score of the model : 0.973984375

# %%
#confusion matrix for test data
print("Confusion matrix for test data :")
skplt.metrics.plot_confusion_matrix(y_test,predict1)
##confusiion matrix for train data
print("Confusion matrix for train data :")
skplt.metrics.plot_confusion_matrix(y_train,predict2)
# Out:
# Confusion matrix for test data :
# Confusion matrix for train data :

# %%
train_fpr, train_tpr, thresholds = roc_curve(y_train, clf.predict_proba(X_train)[:,1])
test_fpr, test_tpr, thresholds1 = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
plt.plot(train_fpr, train_tpr, label="train AUC ="+str(metrics.auc(train_fpr, train_tpr)))
plt.plot(test_fpr, test_tpr, label="test AUC ="+str(metrics.auc(test_fpr, test_tpr)))
plt.legend()
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC curve")
plt.show()

# %%
train_score = 500*0+999*10
test_score = 10*500+426*10
print("Training score using given metric : ",train_score)
print("Test score using given metric :",test_score)
# Out:
# Training score using given metric :  9990
# Test score using given metric : 9260

# %% [markdown]
# ## Conclusion

# %%
x = PrettyTable()
print("Using Expect Maximization for Imputation:")
x.field_names = (["Imputation Technique", "Train Accuracy","Test Accuracy","500*FN+10*FN Train","500*FN+10*TN Test", "Classifier"])
x.add_row(["Expect_Max", 0.9668, 0.96291, 47510,18170,"Naive Bayes"])
x.add_row(["Expect_Max",0.9814,.98,7120, 13620,"Random Forest"])
x.add_row(["Expect_Max",0.97289,.96225,10400,9430,"XGboost"])
print(x)


x = PrettyTable()
print("Using Mean for Imputation:")
x.field_names = (["Mean", "Train Accuracy","Test Accuracy","500*FN+10*FN Train","500*FN+10*TN Test", "Classifier"])
x.add_row(["Mean",0.9658,0.9619,50400,12370,"Naive Bayes"])
x.add_row(["Mean", 0.97,0.94975,10660,17020,"Random Forest"])
x.add_row(["Mean", 0.9739, 0.9636,9990, 9260,"XGboost"])
print(x)
# Out:
# Using Expect Maximization for Imputation:
# +----------------------+----------------+---------------+--------------------+-------------------+---------------+
# | Imputation Technique | Train Accuracy | Test Accuracy | 500*FN+10*FN Train | 500*FN+10*TN Test |   Classifier  |
# +----------------------+----------------+---------------+--------------------+-------------------+---------------+
# |      Expect_Max      |     0.9668     |    0.96291    |       47510        |       18170       |  Naive Bayes  |
# |      Expect_Max      |     0.9814     |      0.98     |        7120        |       13620       | Random Forest |
# |      Expect_Max      |    0.97289     |    0.96225    |       10400        |        9430       |    XGboost    |
# +----------------------+----------------+---------------+--------------------+-------------------+---------------+
# Using Mean for Imputation:
# +------+----------------+---------------+--------------------+-------------------+---------------+
# | Mean | Train Accuracy | Test Accuracy | 500*FN+10*FN Train | 500*FN+10*TN Test |   Classifier  |
# +------+----------------+---------------+--------------------+-------------------+---------------+
# | Mean |     0.9658     |     0.9619    |       50400        |       12370       |  Naive Bayes  |
# | Mean |      0.97      |    0.94975    |       10660        |       17020       | Random Forest |
# | Mean |     0.9739     |     0.9636    |        9990        |        9260       |    XGboost    |
# +------+----------------+---------------+--------------------+-------------------+---------------+

# %% [markdown]
# 1. From the above table we can see that we are getting maximum accuracy .9814 for RandomForest when using em as method for imputation
# 2. We are getting optimal 500*FN + 10*TN (9260) when using XGboost when using Mean as method for imputation.

# %% [markdown]
# ## Steps Taken

# %% [markdown]
# 1. Download the dataset.
# 2. Check for the NAN values in the dataset.
# 3. Remove the columns having more than 50% values as NAN.
# 4. Fill the nan values using various methods such as Mean, Expect_Maximization, and Soft Impute.
# 5. Break the dataset into train test and cv.
# 6. Perform the hyperparameter tunning.
# 7. Conclude the result.
